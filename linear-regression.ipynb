# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score

# %%
z = pd.read_csv('/kaggle/input/random-linear-regression/train.csv')

# %%
z.head()
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
z.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
z.shape
# Out:
# (700, 2)

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
z.duplicated().sum()
# Out:
# 0

# %%
z.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
z = z.dropna()

# %%
z.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
z.shape
# Out:
# (699, 2)

# %% [markdown]
# # **#EDA**

# %%
plt.scatter(z['x'],z['y'])
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.boxplot(z)
plt.xlabel('X')
plt.ylabel('Y')
plt.plot()
# Out:
# []

# %% [markdown]
# ****

# %%
x = z['x'].values

# %%
y =z['y'].values

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y)

# %%
x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(f"Interept Is {model.intercept_}")
print(f"Coificent is{model.coef_}")
# Out:
# Interept Is -0.1535563540732099
# Coificent is[1.00308816]

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test , y_pred)

# %%
print(f"Mean squared Error {mse}")
# Out:
# Mean squared Error 8.278602744853353

# %%
r2 = r2_score(y_test,y_pred)

# %%
print(f"r2 Score is{r2}")
# Out:
# r2 Score is0.9896108569754257

# %%
x = x.reshape(-1,1)

# %%
plt.scatter(x,y, color='blue', label = "Data Point")
plt.scatter(x, model.predict(x),color = "red",label = "Regression line")
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title("Linear Regression Example")
plt.legend()
plt.show()

# %%
#For testing data

# %%
test = pd.read_csv('/kaggle/input/random-linear-regression/test.csv')

# %%
test.shape
# Out:
# (300, 2)

# %%
test.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
sample = test['x'].values

# %%
sample = sample.reshape(-1,1)

# %%
sample_pred = model.predict(sample)

# %%
test['sample_pred'] =sample_pred

# %%
test.head()
# Out:
#     x          y  sample_pred
# 0  77  79.775152    77.084232
# 1  21  23.177279    20.911295
# 2  22  25.609262    21.914383
# 3  20  17.857388    19.908207
# 4  36  41.849864    35.957618

# %%
plt.scatter(test['x'] , test['y'], color = 'blue' ,label = 'Data Point' )
plt.scatter(test['x'] , test['sample_pred'], color = 'red' ,label = 'Data Point' )
plt.xlabel('height(cm)')
plt.ylabel('weight (kg)')
plt.title("Lenear Regression example")

plt.legend()
plt.show()
