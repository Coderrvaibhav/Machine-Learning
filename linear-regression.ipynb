# %% [markdown]
# <a href="https://www.kaggle.com/code/vaibhavpawar41/linear-regression?scriptVersionId=196377805" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
#  # **Import Library**

# %% [markdown]
# ****

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score

# %%
z = pd.read_csv('/kaggle/input/random-linear-regression/train.csv')

# %%
z.head()
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
z.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
z.shape
# Out:
# (700, 2)

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
z.duplicated().sum()
# Out:
# 0

# %%
z.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
z = z.dropna()

# %%
z.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
z.shape
# Out:
# (699, 2)

# %% [markdown]
# # **#EDA**

# %%
plt.scatter(z['x'],z['y'])
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.boxplot(z)
plt.xlabel('X')
plt.ylabel('Y')
plt.plot()
# Out:
# []

# %% [markdown]
# ****

# %% [markdown]
# # Split the Data

# %%
x = z['x'].values

# %%
y =z['y'].values

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y)

# %%
x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

# %%
model = LinearRegression()

# %% [markdown]
# # Train the model

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Linear Regression
#
# The formula for the **Linear Regression** model is:
#
# $$
# y = \beta_0 + \beta_1 x
# $$
#
# where:
#
# - \( y \) is the dependent variable (target value).
# - \( x \) is the independent variable (feature).
# - \( \beta_0 \) is the y-intercept.
# - \( \beta_1 \) is the slope of the line.
#
# To calculate the slope \( \beta_1 \) and intercept \( \beta_0 \), we use the following formulas:
#
# $$
# \beta_1 = \frac{\sum_{i=1}^{n} (x_i - \bar{x}) \times (y_i - \bar{y})}{\sum_{i=1}^{n} (x_i - \bar{x})^2}
# $$
#
# $$
# \beta_0 = \bar{y} - \beta_1 \bar{x}
# $$
#
# where:
#
# - (bar x ) is the mean of the independent variable \( x \).
# -  (bar y ) is the mean of the dependent variable \( y \).
# - ( n ) is the number of data points.

# %%
print(f"Interept Is {model.intercept_}")
print(f"Coificent is{model.coef_}")
# Out:
# Interept Is 0.044795206206785565
# Coificent is[0.99888386]

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# # accuracy

# %%
mse = mean_squared_error(y_test , y_pred)

# %%
print(f"Mean squared Error {mse}")
# Out:
# Mean squared Error 7.440755153745102

# %% [markdown]
# The formula for Mean Squared Error (MSE) is:
#
# $$
# \text{MSE} = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# $$
#
# where:
#
# - \( y_i \) is the actual value.
# - \( \hat{y}_i \) is the predicted value.
# - \( n \) is the number of data points.

# %%
r2 = r2_score(y_test,y_pred)

# %%
print(f"r2 Score is{r2}")
# Out:
# r2 Score is0.9911022675786897

# %% [markdown]
# The formula for \( R^2 \) is:
#
# $$
# R^2 = 1 - \frac{\text{SS}_{\text{res}}}{\text{SS}_{\text{tot}}}
# $$
#
#
#
# where:
#
# - \( \text{SS}_{\text{res}} \) is the Residual Sum of Squares:
# $$
# \text{SS}_{\text{res}} = \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# $$
#
#
#
# - \( \text{SS}_{\text{tot}} \) is the Total Sum of Squares:
# $$
# \text{SS}_{\text{tot}} = \sum_{i=1}^{n} (y_i - \bar{y})^2
# $$
#
#
#
# Here:
#
# - \( y_i \) is the actual value.
# - \( \hat{y}_i \) is the predicted value.
# - \( \bar{y} \) is the mean of the actual values.
# - \( n \) is the number of data points.

# %%
x = x.reshape(-1,1)

# %%
plt.scatter(x,y, color='blue', label = "Data Point")
plt.scatter(x, model.predict(x),color = "red",label = "Regression line")
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title("Linear Regression Example")
plt.legend()
plt.show()

# %%
#For testing data

# %%
test = pd.read_csv('/kaggle/input/random-linear-regression/test.csv')

# %%
test.shape
# Out:
# (300, 2)

# %%
test.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
sample = test['x'].values

# %%
sample = sample.reshape(-1,1)

# %%
sample_pred = model.predict(sample)

# %%
test['sample_pred'] =sample_pred

# %%
test.head()
# Out:
#     x          y  sample_pred
# 0  77  79.775152    76.958853
# 1  21  23.177279    21.021356
# 2  22  25.609262    22.020240
# 3  20  17.857388    20.022472
# 4  36  41.849864    36.004614

# %%
plt.scatter(test['x'] , test['y'], color = 'blue' ,label = 'Data Point' )
plt.scatter(test['x'] , test['sample_pred'], color = 'red' ,label = 'Data Point' )
plt.xlabel('height(cm)')
plt.ylabel('weight (kg)')
plt.title("Lenear Regression example")

plt.legend()
plt.show()
